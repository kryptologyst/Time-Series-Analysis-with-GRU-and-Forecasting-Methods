# %% [markdown]
# # Time Series Analysis with GRU - Example Notebook
#
# This notebook demonstrates the key features of the time series analysis project.
#
# ## Overview
# - Load and preprocess time series data
# - Train GRU neural network
# - Compare multiple forecasting methods
# - Detect anomalies
# - Visualize results
